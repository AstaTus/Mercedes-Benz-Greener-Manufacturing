# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('../data/original/train.csv', index_col=0)

# %%
train_df.head()
# Out:
#          y  X0 X1  X2 X3 X4 X5 X6 X8  X10  ...   X375  X376  X377  X378  X379  \
# ID                                         ...
# 0   130.81   k  v  at  a  d  u  j  o    0  ...      0     0     1     0     0
# 6    88.53   k  t  av  e  d  y  l  o    0  ...      1     0     0     0     0
# 7    76.26  az  w   n  c  d  x  j  x    0  ...      0     0     0     0     0
# 9    80.62  az  t   n  f  d  x  l  e    0  ...      0     0     0     0     0
# 13   78.02  az  v   n  f  d  h  d  n    0  ...      0     0     0     0     0
#
#     X380  X382  X383  X384  X385
# ID
# 0      0     0     0     0     0
# 6      0     0     0     0     0
# 7      0     1     0     0     0
# 9      0     0     0     0     0
# 13     0     0     0     0     0
#
# [5 rows x 377 columns]

# %%
onehot_df = munge_onehot(train_df)
#munged_train_df = munged_train_df.join(onehot_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d88c4c102742> in <module>()
#       1 onehot_df = munge_onehot(train_df)
# ----> 2 munged_train_df = munged_train_df.join(onehot_df)
#
# NameError: name 'munged_train_df' is not defined

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
train_df['X0_Trans'] = le.fit_transform(train_df['X0'])
train_df['X1_Trans'] = le.fit_transform(train_df['X1'])
train_df['X2_Trans'] = le.fit_transform(train_df['X2'])
train_df['X3_Trans'] = le.fit_transform(train_df['X3'])
train_df['X4_Trans'] = le.fit_transform(train_df['X4'])
train_df['X5_Trans'] = le.fit_transform(train_df['X5'])
train_df['X6_Trans'] = le.fit_transform(train_df['X6'])
train_df['X8_Trans'] = le.fit_transform(train_df['X8'])

# %%
train_df[train_df['y'] > 250]
# Out:
# Empty DataFrame
# Columns: [y, X0, X1, X2, X3, X4, X5, X6, X8, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X20, X21, X22, X23, X24, X26, X27, X28, X29, X30, X31, X32, X33, X34, X35, X36, X37, X38, X39, X40, X41, X42, X43, X44, X45, X46, X47, X48, X49, X50, X51, X52, X53, X54, X55, X56, X57, X58, X59, X60, X61, X62, X63, X64, X65, X66, X67, X68, X69, X70, X71, X73, X74, X75, X76, X77, X78, X79, X80, X81, X82, X83, X84, X85, X86, X87, X88, X89, X90, X91, X92, X93, X94, X95, X96, X97, X98, X99, X100, X101, X102, ...]
# Index: []
#
# [0 rows x 385 columns]

# %%
train_df.drop(1770, inplace=True)

# %%
sns.lmplot(x='X0_Trans', y='y', data=train_df)
plt.show()

# %%
sns.lmplot(x='X1_Trans', y='y', data=train_df)
plt.show()

# %%
sns.lmplot(x='X2_Trans', y='y', data=train_df)
plt.show()

# %%
sns.lmplot(x='X3_Trans', y='y', data=train_df)
plt.show()

# %%
sns.lmplot(x='X4_Trans', y='y', data=train_df)
plt.show()

# %%
train_df[train_df['X4_Trans'] < 2.5]
# Out:
#            y  X0 X1  X2 X3 X4  X5 X6 X8  X10    ...     X384  X385  X0_Trans  \
# ID                                              ...
# 2581  112.80  ap  l   s  c  b  ac  j  l    0    ...        0     0        12
# 2584  134.04  ak  e  ap  c  c  ac  j  j    0    ...        0     0         8
# 2585   96.69   z  r  ae  c  a  ac  a  s    0    ...        0     0        46
# 2586  105.51  aj  u  as  c  a  ac  d  n    0    ...        0     0         7
#
#       X1_Trans  X2_Trans  X3_Trans  X4_Trans  X5_Trans  X6_Trans  X8_Trans
# ID
# 2581        13        39         2         1         2         9        11
# 2584         6        13         2         2         2         9         9
# 2585        19         3         2         0         2         0        18
# 2586        22        16         2         0         2         3        13
#
# [4 rows x 385 columns]

# %%
train_df.drop([2581, 2584, 2585, 2586], inplace=True)

# %%
sns.lmplot(x='X5_Trans', y='y', data=train_df)
plt.show()

# %%
sns.lmplot(x='X6_Trans', y='y', data=train_df)
plt.show()

# %%
sns.lmplot(x='X8_Trans', y='y', data=train_df)
plt.show()

# %%
train_df[train_df['y'] > 160]
# Out:
#            y  X0 X1  X2 X3 X4  X5 X6 X8  X10    ...     X384  X385  X0_Trans  \
# ID                                              ...
# 681   169.91  aa  l  ak  f  d   i  c  d    0    ...        0     0         1
# 2396  160.87   j  o  as  f  d  ab  g  p    0    ...        0     0        31
# 2903  167.45  ai  b  ae  a  d  ac  g  m    0    ...        0     0         6
# 6273  165.52  aj  v   r  c  d   q  g  a    0    ...        0     0         7
#
#       X1_Trans  X2_Trans  X3_Trans  X4_Trans  X5_Trans  X6_Trans  X8_Trans
# ID
# 681         13         8         5         0        13         2         3
# 2396        16        16         5         0         1         6        15
# 2903         3         3         0         0         2         6        12
# 6273        23        38         2         0        21         6         0
#
# [4 rows x 385 columns]

# %%
[681, 2396, 2903, 6273]
